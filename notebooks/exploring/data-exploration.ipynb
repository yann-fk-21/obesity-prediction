# %% [markdown]
# ### Importing dependencies

# %%
import numpy as np
import pandas as pd

from src.data.load_data import load_data_csv
from src.visualization.visualization import plot_count_values, plot_scatter, plot_hist, plot_corr_matrix

# %% [markdown]
# ### Loading and exploring data
# The data is in CSV format

# %%
obesity_data = load_data_csv("../../data/raw/ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
obesity_data.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
obesity_data.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
obesity_data.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.315964     1.701620    86.586035     2.418986     2.685651
# std       6.357078     0.093368    26.191163     0.533996     0.778079
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      20.000000     1.630000    65.470000     2.000000     2.660000
# 50%      23.000000     1.700000    83.000000     2.390000     3.000000
# 75%      26.000000     1.770000   107.430000     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008053     1.010313     0.657861
# std       0.612950     0.850613     0.608926
# min       1.000000     0.000000     0.000000
# 25%       1.585000     0.125000     0.000000
# 50%       2.000000     1.000000     0.625000
# ...

# %%
obesity_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
obesity_data.dtypes
# Out:
# Gender                             object
# Age                                 int64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
obesity_data.isna().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
obesity_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2106    False
# 2107    False
# 2108    False
# 2109    False
# 2110    False
# Length: 2111, dtype: bool

# %%
obesity_data[obesity_data.duplicated()]
# Out:
#      Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 98   Female   21    1.52    42.0                             no   no   3.0
# 106  Female   25    1.57    55.0                             no  yes   2.0
# 174    Male   21    1.62    70.0                             no  yes   2.0
# 179    Male   21    1.62    70.0                             no  yes   2.0
# 184    Male   21    1.62    70.0                             no  yes   2.0
# 209  Female   22    1.69    65.0                            yes  yes   2.0
# 309  Female   16    1.66    58.0                             no   no   2.0
# 460  Female   18    1.62    55.0                            yes  yes   2.0
# 467    Male   22    1.74    75.0                            yes  yes   3.0
# 496    Male   18    1.72    53.0                            yes  yes   2.0
# 527  Female   21    1.52    42.0                             no  yes   3.0
# ...

# %% [markdown]
# ### Visualizing data

# %%
obesity_data.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history_with_overweight',
#        'FAVC', 'FCVC', 'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE',
#        'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
plot_count_values(obesity_data, target="Gender")

# %%
obesity_data.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  NCP  \
# 0  Female   21    1.62    64.0                            yes   no   2.0  3.0
# 1  Female   21    1.52    56.0                            yes   no   3.0  3.0
# 2    Male   23    1.80    77.0                            yes   no   2.0  3.0
# 3    Male   27    1.80    87.0                             no   no   3.0  3.0
# 4    Male   22    1.78    89.8                             no   no   2.0  1.0
#
#         CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0  Sometimes    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2  Sometimes    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3  Sometimes    no   2.0   no  2.0  0.0  Frequently                Walking
# 4  Sometimes    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#             NObeyesdad
# ...

# %%
plot_count_values(obesity_data, target="CAEC")

# %%
plot_count_values(obesity_data, target="SMOKE")

# %%
plot_scatter(obesity_data, x="SMOKE", y="Age", hue=obesity_data.NObeyesdad)

# %%
plot_hist(obesity_data["CH2O"], bins=50)

# %%
plot_hist(obesity_data["TUE"],bins=50)

# %%
plot_scatter(obesity_data, x="Weight", y="Age", hue=obesity_data.NObeyesdad)

# %%
plot_count_values(obesity_data, target="NObeyesdad")

# %%
plot_count_values(obesity_data, target="MTRANS")
